# %% [markdown]
# <a href="https://colab.research.google.com/github/Rad-Monk/TF-Notebooks/blob/main/SIMCLR_dfd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### loading all the data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d ahmadawad732/uadfv-dataset-new
# !unzip uadfv-dataset-new.zip

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

filepath = '/content/fake_videos/'
# filepath = '/content/drive/MyDrive/deep_fake/' # for the 10gb dataset from drive

train_data = []
val_data = []
test_data = []

### DATASET 1 (FaceForensics + Celeb)
for dirname, _, filenames in os.walk(filepath):
    for filename in filenames:
        if 'validation' in dirname:
            val_data.append(os.path.normpath(os.path.join(dirname, filename)))
        elif 'train' in dirname:
            train_data.append(os.path.normpath(os.path.join(dirname, filename)))
        else:
            test_data.append(os.path.normpath(os.path.join(dirname, filename)))

# Normalize paths to use forward slashes
train_data = [filepath.replace("\\", "/") for filepath in train_data]
val_data = [filepath.replace("\\", "/") for filepath in val_data]
test_data = [filepath.replace("\\", "/") for filepath in test_data]

# %%
os.listdir(filepath)

# %%
train_data
# val_data
# test_data
# Out:
# ['/content/drive/MyDrive/deep_fake/train/fake/023_M113.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/007_W101.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/315_W006.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/318_W006.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/050_M115.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/005_W101.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/059_M118.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/351_M023.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/270_M015.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/451_M138.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/191_W032.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/247_W040.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/223_W037.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/075_W014.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/185_M008.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/179_M007.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/183_M007.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/003_M101.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/215_W036.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/244_W040.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/010_W006.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/168_W029.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/257_W042.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/052_W012.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/234_M012.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/193_W032.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/231_W136.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/326_M021.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/038_W009.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/357_M024.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/013_W006.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/279_M134.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/350_W131.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/025_W007.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/195_M008.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/330_W008.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/184_W031.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/317_W006.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/304_M019.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/001_W101.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/205_W135.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/210_M010.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/022_M109.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/356_M024.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/448_M034.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/259_M014.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/214_W035.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/310_M019.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/453_W024.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/288_W125.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/294_W100.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/281_W116.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/206_W135.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/218_M011.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/209_M010.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/057_W012.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/254_W042.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/443_M137.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/282_W116.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/352_M024.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/021_W007.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/201_W134.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/181_M007.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/170_W029.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/312_W101.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/036_M114.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/253_M014.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/303_M105.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/333_M021.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/020_M109.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/069_W013.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/203_W134.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/058_M117.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/341_W010.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/171_M133.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/039_M114.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/335_M022.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/040_W010.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/225_W037.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/263_W111.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/060_W012.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/232_W039.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/251_W041.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/064_M118.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/325_M021.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/202_W134.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/242_W040.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/261_W110.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/037_W009.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/208_W035.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/032_W009.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/068_W013.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/269_M015.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/071_M119.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/028_W008.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/464_M139.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/458_W025.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/012_W006.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/238_W039.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/245_M013.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/029_W008.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/260_W110.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/355_W012.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/014_M131.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/076_W014.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/347_M023.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/295_W100.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/349_W131.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/197_M009.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/248_W041.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/290_W125.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/008_W101.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/182_W133.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/299_M105.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/459_W025.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/078_M119.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/235_M012.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/276_M016.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/221_W037.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/345_M023.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/307_M019.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/272_W112.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/289_M134.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/267_M015.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/445_M034.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/169_W029.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/442_M137.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/460_W026.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/047_W131.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/343_M022.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/174_W029.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/342_M022.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/266_M014.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/292_W125.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/228_M011.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/301_M105.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/256_W042.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/065_W005.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/204_W135.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/311_M135.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/194_M008.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/220_W036.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/031_M113.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/329_W008.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/017_W006.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/452_M138.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/268_M015.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/192_W032.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/321_W007.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/331_W009.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/283_M134.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/176_W133.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/457_W025.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/455_W025.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/241_M013.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/327_W008.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/044_M115.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/463_M139.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/332_W009.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/309_W101.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/175_M133.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/063_M118.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/027_M113.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/026_W008.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/079_W014.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/291_M018.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/447_M034.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/213_W035.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/284_W116.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/461_W026.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/212_M010.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/030_W008.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/048_W131.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/246_W040.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/348_W131.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/053_W012.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/456_M138.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/300_M018.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/296_W100.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/322_W007.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/297_M018.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/199_M009.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/233_W039.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/334_W009.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/049_W131.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/077_M119.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/024_M113.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/440_M137.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/222_W037.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/462_W026.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/046_W010.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/219_W036.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/072_W013.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/275_W112.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/454_W024.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/188_W031.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/305_W101.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/328_W008.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/252_M014.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/441_W023.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/316_W006.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/066_W005.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/055_M117.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/015_M109.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/226_M011.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/018_W007.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/249_W041.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/313_M135.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/274_W112.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/287_W125.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/277_M016.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/190_W032.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/224_M011.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/178_W133.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/308_W101.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/273_M016.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/041_M115.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/278_M016.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/323_W007.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/173_M133.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/211_W035.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/265_W111.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/056_M117.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/074_W014.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/196_M009.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/054_M117.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/354_W012.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/285_W116.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/444_M034.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/217_W036.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/006_M131.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/465_W026.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/239_M013.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/280_W112.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/250_W041.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/180_M007.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/255_W042.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/009_M131.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/227_W136.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/000_M101.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/002_M101.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/051_W131.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/336_W009.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/286_M134.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/344_W131.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/340_W010.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/293_W100.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/042_W010.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/172_M133.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/073_M119.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/314_M135.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/243_M013.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/033_M114.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/062_W005.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/339_W010.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/320_W007.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/229_W136.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/306_M019.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/186_W031.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/216_M010.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/045_W010.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/337_M022.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/070_W013.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/167_W028.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/450_W024.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/439_W023.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/043_M115.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/302_M105.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/177_W133.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/187_M008.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/019_W007.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/061_M118.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/346_M023.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/324_M021.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/198_M009.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/067_W005.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/004_M101.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/237_M012.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/446_W024.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/207_W135.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/016_M109.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/338_W010.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/353_M024.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/264_W111.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/262_W110.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/258_W110.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/200_W134.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/035_M114.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/319_M135.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/449_M138.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/236_M012.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/240_W039.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/438_W023.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/298_M018.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/271_W111.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/034_W009.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/230_W136.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/166_W028.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/011_M131.mp4',
#  '/content/drive/MyDrive/deep_fake/train/fake/189_W031.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_angry_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_angry_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_happy_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_happy_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_angry_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_happy_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_happy_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_happy_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_happy_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_angry_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_angry_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_angry_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_angry_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_disgust_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_contempt_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_disgust_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_contempt_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_disgust_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_contempt_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_contempt_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_contempt_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_disgust_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_disgust_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_contempt_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_disgust_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_disgust_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_neutral_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_fear_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_fear_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_neutral_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_fear_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_neutral_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_fear_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_fear_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_fear_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_up_fear_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_uniform_surprise_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_uniform_surprise_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_light_uniform_surprise_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_BlendShape_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_BlendShape_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_BlendShape_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_BlendShape_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_BlendShape_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M004_BlendShape_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_disgust_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_disgust_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_disgust_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_disgust_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_neutral_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_neutral_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_neutral_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_disgust_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_neutral_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_neutral_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_disgust_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_neutral_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_fear_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_fear_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_fear_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_fear_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftup_angry_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_angry_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_angry_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_angry_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_angry_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_angry_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_angry_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_contempt_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_disgust_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_contempt_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_contempt_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_disgust_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_disgust_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_disgust_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_contempt_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_disgust_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_disgust_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_contempt_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_contempt_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_disgust_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_surprise_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_fear_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_left_fear_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_surprise_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_sad_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_sad_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_surprise_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_sad_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_neutral_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_surprise_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_surprise_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_neutral_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_sad_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_sad_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_neutral_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_surprise_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_neutral_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_sad_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_neutral_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_down_neutral_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_angry_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_angry_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_contempt_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_angry_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_angry_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_contempt_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_contempt_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_angry_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_angry_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_contempt_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_contempt_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_contempt_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_neutral_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_sad_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_disgust_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_sad_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_sad_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_happy_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_disgust_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_fear_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_neutral_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_happy_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_disgust_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_disgust_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_sad_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_sad_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_disgust_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_fear_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_fear_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_happy_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_happy_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_neutral_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_fear_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_fear_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_happy_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_contempt_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_disgust_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_fear_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_fear_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_happy_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_sad_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_sad_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_happy_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M005_light_left_neutral_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_angry_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_angry_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_angry_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_angry_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_contempt_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_angry_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_contempt_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_neutral_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_fear_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_happy_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_disgust_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_neutral_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_contempt_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_sad_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_neutral_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_disgust_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_neutral_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_contempt_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_happy_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_happy_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_disgust_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_sad_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_fear_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_disgust_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_fear_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_sad_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_sad_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_neutral_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_neutral_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_fear_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_contempt_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_surprise_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_contempt_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_happy_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_fear_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_disgust_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_sad_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_neutral_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_happy_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_happy_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_fear_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_fear_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_disgust_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_happy_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M007_light_left_sad_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_neutral_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_neutral_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_neutral_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_neutral_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_right_angry_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_right_contempt_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_neutral_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_right_angry_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_sad_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_right_angry_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_right_contempt_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_surprise_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_sad_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_right_contempt_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_neutral_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_sad_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_sad_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_surprise_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_surprise_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_surprise_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_surprise_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_sad_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_surprise_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_sad_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_right_contempt_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_leftup_surprise_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_contempt_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_contempt_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_angry_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_disgust_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_angry_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_contempt_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_contempt_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_contempt_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_contempt_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_angry_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_contempt_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_angry_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M008_light_rightdown_disgust_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_contempt_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_angry_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_contempt_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_happy_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_happy_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_sad_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_sad_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_contempt_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_left_surprise_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_angry_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_angry_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_angry_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_happy_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_fear_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_happy_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_happy_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_happy_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_angry_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_angry_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_contempt_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_left_surprise_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_happy_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_contempt_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_contempt_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_sad_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_sad_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_sad_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_sad_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M009_light_leftdown_sad_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_BlendShape_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_BlendShape_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_BlendShape_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_BlendShape_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_disgust_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_contempt_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_disgust_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_contempt_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_fear_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_disgust_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_contempt_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_angry_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_angry_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_angry_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_BlendShape_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_disgust_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_contempt_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_contempt_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_contempt_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_angry_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_disgust_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_contempt_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_angry_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_angry_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_down_fear_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_fear_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_happy_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_fear_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_fear_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_happy_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_happy_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_happy_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_happy_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_happy_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_neutral_camera_down.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_neutral_camera_front.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_neutral_camera_right.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_neutral_camera_rightfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_happy_camera_up.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_neutral_camera_leftfront.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M010_light_leftdown_neutral_camera_left.mp4',
#  '/content/drive/MyDrive/deep_fake/train/real/M011_light_uniform_angry_camera_up.mp4']

# %%
pip install tensorflow opencv-python-headless

# %%
train_data

# %%
import shutil
import os

# Specify the directory you want to delete
train_directory_path = '/content/train_data_frames'
val_directory_path = '/content/val_data_frames'
test_directory_path = '/content/test_data_frames'

# Check if the directory exists
def remove_directory(directory_path):
  if os.path.exists(directory_path):
    # Remove the directory and all its contents
    shutil.rmtree(directory_path)
    print(f"Directory '{directory_path}' has been deleted.")
  else:
    print(f"Directory '{directory_path}' does not exist.")

remove_directory(train_directory_path)
remove_directory(val_directory_path)
remove_directory(test_directory_path)

# %% [markdown]
# ### Extracting Frames and Pre-processing

# %%
import os
import cv2

def extract_frames_from_videos(video_dir, output_dir, frame_rate=5):
    """
    Extracts frames from videos and saves them to the output directory.

    Parameters:
    video_dir (str): Directory containing video files.
    output_dir (str): Directory to save extracted frames.
    frame_rate (int): Extract 1 frame per 'frame_rate' seconds of the video.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # for video_name in os.listdir(video_dir):
    for video_path in video_dir:
        # video_path = os.path.join(video_dir, video_name)
        cap = cv2.VideoCapture(video_path)
        count = 0

        while cap.isOpened():
            frame_id = int(cap.get(cv2.CAP_PROP_POS_FRAMES))
            ret, frame = cap.read()

            if not ret:
                break

            if frame_id % (frame_rate * int(cap.get(cv2.CAP_PROP_FPS))) == 0:
                frame_name = f"{(os.path.splitext(video_path)[0]).split('/')[-1]}_frame{frame_id}.jpg"
                frame_path = os.path.join(output_dir, frame_name)
                cv2.imwrite(frame_path, frame)

            count += 1

        cap.release()


train_directory = '/content/train_data_frames'
val_directory = '/content/val_data_frames'
test_directory = '/content/test_data_frames'
extract_frames_from_videos(train_data, train_directory)
extract_frames_from_videos(val_data, val_directory)
extract_frames_from_videos(test_data, test_directory)
# extract_frames_from_videos(filepath + '/train/real', output_directory)
# extract_frames_from_videos(filepath + '/train/fake', output_directory)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-4985b48ba4f6> in <cell line: 42>()
#      40 val_directory = '/content/val_data_frames'
#      41 test_directory = '/content/test_data_frames'
# ---> 42 extract_frames_from_videos(train_data, train_directory)
#      43 extract_frames_from_videos(val_data, val_directory)
#      44 extract_frames_from_videos(test_data, test_directory)
#
# <ipython-input-7-4985b48ba4f6> in extract_frames_from_videos(video_dir, output_dir, frame_rate)
#      22         while cap.isOpened():
#      23             frame_id = int(cap.get(cv2.CAP_PROP_POS_FRAMES))
# ---> 24             ret, frame = cap.read()
#      25
#      26             if not ret:
#
# KeyboardInterrupt:

# %%
import tensorflow as tf

# Path to the directory containing all frames
train_frames_dir = '/content/train_data_frames'
val_frames_dir = '/content/val_data_frames'

# Define the preprocessing function
def preprocess_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [224, 224])  # Resize to a fixed size
    image = tf.image.random_flip_left_right(image)  # Data augmentation
    image = tf.image.random_brightness(image, max_delta=0.5)
    image = tf.image.per_image_standardization(image)  # Normalize the image
    return image

# Create a TensorFlow dataset
batch_size = 4
train_dataset = tf.data.Dataset.list_files(f"{train_frames_dir}/*.jpg")
train_dataset = train_dataset.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.list_files(f"{val_frames_dir}/*.jpg")
val_dataset = val_dataset.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Example of iterating through the dataset
for batch in train_dataset.take(1):
    print(batch.shape)  # Should print (batch_size, 224, 224, 3)

# %% [markdown]
# ### Creating the SimClR Model

# %%
# !pip install tensorflow tensorflow-hub

# %%
train_dataset

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.layers import Layer

# Define the encoder (EfficientNetB4) from TensorFlow Keras applications
def create_encoder():
    base_model = tf.keras.applications.EfficientNetB4(
        include_top=False,
        weights='imagenet',  # Use pretrained weights
        input_shape=(224, 224, 3),
        pooling='avg'  # Global average pooling
    )
    return base_model

# Define the projection head
def create_projection_head(encoder_output, projection_dim=128):
    x = layers.Dense(512, activation='relu')(encoder_output)
    x = layers.Dense(projection_dim)(x)
    return x

# Wrap custom layer in Layer so that it doesn't affect computation graph
def apply_normalize(projection, axis=1):
    return tf.math.l2_normalize(projection, axis=axis)

class My_normalize_layer(Layer):
    def __init__(self, axis=1, **kwargs):
        super(My_normalize_layer, self).__init__(**kwargs)
    def call(self, projection, axis=1):
        return apply_normalize(projection, axis=1)


# Create the SimCLR model
def create_simclr_model(projection_dim=128):
    inputs = layers.Input(shape=(224, 224, 3))
    encoder = create_encoder()
    features = encoder(inputs)
    projection = create_projection_head(features, projection_dim)

    # Normalize projection head output
    projection = My_normalize_layer()(projection, axis=1)

    # Build and compile the SimCLR model
    model = Model(inputs=inputs, outputs=projection, name="SimCLR_EfficientNetB4")
    return model

# Instantiate the SimCLR model, uncomment during first execution
simclr_model = create_simclr_model()
simclr_model.summary()

# %%
import tensorflow as tf

def nt_xent_loss(embeddings, temperature=0.5):
    """
    Compute the NT-Xent loss for a batch of embeddings.

    Parameters:
    embeddings (tf.Tensor): The embeddings from the projection head (shape: [2*batch_size, projection_dim]).
                            The first batch_size embeddings correspond to the first set of augmentations,
                            and the next batch_size correspond to the second set of augmentations.
    temperature (float): The temperature scaling factor.

    Returns:
    tf.Tensor: Scalar NT-Xent loss.
    """
    # Normalize the embeddings to have unit norm
    embeddings = tf.math.l2_normalize(embeddings, axis=1)

    # Compute the similarity matrix
    similarity_matrix = tf.matmul(embeddings, embeddings, transpose_b=True)

    # Extract positive pairs (diagonal elements from each block)
    batch_size = tf.shape(embeddings)[0] // 2
    labels = tf.range(batch_size)

    positive_mask = tf.eye(batch_size)
    positive_sim = tf.linalg.diag_part(similarity_matrix[:batch_size, batch_size:])

    # Mask out positive pairs from the similarity matrix
    similarity_matrix = similarity_matrix * (1 - tf.eye(2 * batch_size))

    # Scale by temperature
    similarity_matrix /= temperature

    # Compute the labels for cross-entropy
    labels = tf.concat([labels, labels], axis=0)

    # Compute log_softmax over the similarity matrix
    logits = similarity_matrix - tf.reduce_max(similarity_matrix, axis=1, keepdims=True)
    exp_logits = tf.exp(logits)
    log_softmax = logits - tf.math.log(tf.reduce_sum(exp_logits, axis=1, keepdims=True))

    # Calculate the NT-Xent loss
    positive_log_softmax = tf.concat([log_softmax[:batch_size, batch_size:], log_softmax[batch_size:, :batch_size]], axis=0)
    positive_log_softmax = tf.reduce_mean(tf.linalg.diag_part(positive_log_softmax))

    loss = -positive_log_softmax
    return loss

# %%
import os

# Directory to save the model weights
checkpoint_dir = '/content/'
os.makedirs(checkpoint_dir, exist_ok=True)


# Training parameters
num_epochs = 10
learning_rate = 0.001
temperature = 0.5

# Optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate)

# Training loop
for epoch in range(num_epochs):
    total_loss = 0.0
    num_batches = 0

    # Training step
    for batch in train_dataset:
        with tf.GradientTape() as tape:
            # Forward pass
            embeddings = simclr_model(tf.concat([batch, batch], axis=0), training=True)

            # Compute the NT-Xent loss
            loss = nt_xent_loss(embeddings, temperature)

        # Backward pass
        gradients = tape.gradient(loss, simclr_model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, simclr_model.trainable_variables))

        total_loss += loss
        num_batches += 1

    avg_loss = total_loss / num_batches
    print(f"Epoch {epoch + 1}/{num_epochs}, Training Loss: {avg_loss:.4f}")

    # Validation step
    total_val_loss = 0.0
    num_val_batches = 0

    for val_batch in val_dataset:
        # Forward pass for validation (no gradient tape required)
        val_embeddings = simclr_model(tf.concat([val_batch, val_batch], axis=0), training=False)

        # Compute validation NT-Xent loss
        val_loss = nt_xent_loss(val_embeddings, temperature)

        total_val_loss += val_loss
        num_val_batches += 1

    avg_val_loss = total_val_loss / num_val_batches
    print(f"Epoch {epoch + 1}/{num_epochs}, Validation Loss: {avg_val_loss:.4f}")

    checkpoint_path = os.path.join(checkpoint_dir, f'simclr_epoch_{epoch + 1}.weights.h5')
    simclr_model.save_weights(checkpoint_path)
    print(f"Model weights saved to {checkpoint_path}")

# %% [markdown]
# ### Loading weights again, if you reset after traing the model

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.layers import Layer

# creating the model again from the weights i downloaded so i don't haev to train again, the model creation function is same as before,
# so adding it here again just incase
# just the run the cell above where the function is defined :)

# Load model weights
checkpoint_path = '/content/simclr_epoch_10.weights.h5'  # specify the path to your checkpoint

# now creation of model from function and addding the weights
simclr_model = create_simclr_model()
simclr_model.load_weights(checkpoint_path)
print(f'succesfully loaded weights from {checkpoint_path}')

# %%
# # loading the data again from local, or not, just run the above cells again

# import zipfile
# import os

# # Replace 'your_zip_file.zip' with the name of your uploaded zip file
# zip_file = 'dfd_ds.zip'

# # Define the destination directory
# destination_dir = 'dfd_ds'  # Replace with the name of your destination folder

# with zipfile.ZipFile(zip_file, 'r') as zip_ref:
#     zip_ref.extractall(destination_dir)

# # Verify the extraction
# os.listdir(destination_dir)

# %%
# extract all frames with the function above where you extract the frames

# %% [markdown]
# ## Creating the Classifier with the SimClr extractor

# %% [markdown]
# ### Setting image_dataset_from_directory

# %%
import os
import shutil

def separate_videos_by_label(src_dir):
    """
    Separates videos into 'real' and 'fake' subdirectories based on filename.

    Parameters:
    - src_dir (str): Path to the source directory containing video files.
    """
    real_dir = os.path.join(src_dir, 'real')
    fake_dir = os.path.join(src_dir, 'fake')

    # Create subdirectories for 'real' and 'fake' if they don't exist
    if not os.path.exists(real_dir):
        os.makedirs(real_dir)
    if not os.path.exists(fake_dir):
        os.makedirs(fake_dir)

    # Iterate over files in the source directory
    for filename in os.listdir(src_dir):
        # Skip directories
        if os.path.isdir(os.path.join(src_dir, filename)):
            continue

        # Determine the destination directory
        if 'fake' in filename.lower():
            dest_dir = fake_dir
        else:
            dest_dir = real_dir

        # Move the file to the destination directory
        src_path = os.path.join(src_dir, filename)
        dest_path = os.path.join(dest_dir, filename)
        shutil.move(src_path, dest_path)
        print(f"Moved {filename} to {dest_dir}")

# Example usage
train_directory = '/content/train_data_frames'
val_directory = '/content/val_data_frames'
test_directory = '/content/test_data_frames'
separate_videos_by_label(train_directory)
separate_videos_by_label(val_directory)
separate_videos_by_label(test_directory)

# %%
import tensorflow as tf

batch_size = 32
img_size = (224, 224)

# Define paths to the directories
train_dir = '/content/train_data_frames'
val_dir = '/content/val_data_frames'
test_dir = '/content/test_data_frames'

# Load training dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=img_size,
    batch_size=batch_size,
    shuffle=True
)

# Load validation dataset
val_dataset = tf.keras.utils.image_dataset_from_directory(
    val_dir,
    image_size=img_size,
    batch_size=batch_size,
    shuffle=True
)

# Load test dataset
test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=img_size,
    batch_size=batch_size,
    shuffle=False  # Usually, no shuffling for the test set
)

# Prefetch to improve training speed
train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ### Creating the classifier for fine-tuning

# %%
print(f'layers in simclr model {len(simclr_model.layers)}')

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks for training
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)
checkpoint = ModelCheckpoint('/content/fine_tuned_simCLR_with_Classifier_and_regularization.keras', monitor='val_loss', save_best_only=True)

# %%
  import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

# freezing the weights of the sim_clr model
simclr_model.trainable = False

# Add a classification head with regularization
inputs = tf.keras.Input(shape=(224, 224, 3))
x = simclr_model(inputs, training=False)
# x = layers.BatchNormalization()(x)  # Batch normalization layer
x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)  # L2 regularization
x = layers.Dropout(0.5)(x)  # Dropout for regularization
outputs = layers.Dense(1, activation='sigmoid')(x)

# Create the final model
model = tf.keras.Model(inputs, outputs)

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Fine-tune the classifier
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=10,  # Adjust the number of epochs as needed
    callbacks=[early_stopping, reduce_lr, checkpoint]  # Include callbacks for better training management
)

# don't do this yet, because it's decreasing the accuracy, look into it later
# Unfreeze the base model for further fine-tuning
simclr_model.trainable = True
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-6
                                                 ),  # Lower learning rate for fine-tuning
              loss='binary_crossentropy',
              metrics=['accuracy'])
print('set the weights of simclr to trainable')

# Fine-tune the entire model
history_fine = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=5,  # Additional epochs for fine-tuning
    initial_epoch=history.epoch[-1],
    callbacks=[early_stopping, reduce_lr, checkpoint]  # Include callbacks for better training management
)

# %% [markdown]
# ### Testing the final model

# %%
# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# %% [markdown]
# ### Trying HyperParameter tuning
